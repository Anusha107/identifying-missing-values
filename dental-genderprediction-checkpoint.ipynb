# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot asplt
# Out:
#   File "C:\Users\vmraj\AppData\Local\Temp/ipykernel_11208/279576734.py", line 1
#     import matplotlib.pyplot asplt
#                              ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt

# %%
import saeborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11208/1928886619.py in <module>
# ----> 1 import saeborn as sns
#
# ModuleNotFoundError: No module named 'saeborn'

# %%
import seaborn as sns

# %%
df = pd.read_csv("Dentistry Dataset.csv")

# %%
df.head()
# Out:
#    Sl No  Sample ID  Age  Gender  inter canine distance intraoral  \
# 0      1        NaN   24  Female                            25.06
# 1      2        NaN   22  Female                            25.78
# 2      3        NaN   23  Female                            23.83
# 3      4        NaN   20  Female                            26.12
# 4      5        NaN   20  Female                            26.36
#
#    intercanine distance casts  right canine width intraoral  \
# 0                       25.05                          6.08
# 1                       25.79                          6.13
# 2                       23.83                          5.91
# 3                       26.12                          6.08
# 4                       26.41                          6.09
#
#    right canine width casts  left canine width intraoral  \
# 0                      6.08                         6.09
# 1                      6.13                         6.33
# 2                      5.96                         6.28
# 3                      6.08                         6.56
# 4                      6.09                         6.50
#
#    left canine width casts  right canine index intra oral  \
# 0                     6.10                          0.242
# 1                     6.33                          0.237
# 2                     6.28                          0.248
# 3                     6.56                          0.232
# 4                     6.50                          0.231
#
#    right canine index casts  left canine index intraoral  \
# 0                     0.242                        0.242
# 1                     0.237                        0.247
# 2                     0.248                        0.264
# 3                     0.232                        0.250
# 4                     0.231                        0.246
#
#    left canine index casts
# 0                    0.241
# 1                    0.247
# 2                    0.264
# 3                    0.250
# 4                    0.246

# %%
df.isnull()
# Out:
#       Sl No  Sample ID    Age  Gender  inter canine distance intraoral  \
# 0     False       True  False   False                            False
# 1     False       True  False   False                            False
# 2     False       True  False   False                            False
# 3     False       True  False   False                            False
# 4     False       True  False   False                            False
# ...     ...        ...    ...     ...                              ...
# 1095  False       True  False   False                            False
# 1096  False       True  False   False                            False
# 1097  False       True  False   False                            False
# 1098  False       True  False   False                            False
# 1099  False       True  False   False                            False
#
#       intercanine distance casts  right canine width intraoral  \
# 0                          False                         False
# 1                          False                         False
# 2                          False                         False
# 3                          False                         False
# 4                          False                         False
# ...                          ...                           ...
# 1095                       False                         False
# 1096                       False                         False
# 1097                       False                         False
# 1098                       False                         False
# 1099                       False                         False
#
#       right canine width casts  left canine width intraoral  \
# 0                        False                        False
# 1                        False                        False
# 2                        False                        False
# 3                        False                        False
# 4                        False                        False
# ...                        ...                          ...
# 1095                     False                        False
# 1096                     False                        False
# 1097                     False                        False
# 1098                     False                        False
# 1099                     False                        False
#
#       left canine width casts  right canine index intra oral  \
# 0                       False                          False
# 1                       False                          False
# 2                       False                          False
# 3                       False                          False
# 4                       False                          False
# ...                       ...                            ...
# 1095                    False                          False
# 1096                    False                          False
# 1097                    False                          False
# 1098                    False                          False
# 1099                    False                          False
#
#       right canine index casts  left canine index intraoral  \
# 0                        False                        False
# 1                        False                        False
# 2                        False                        False
# 3                        False                        False
# 4                        False                        False
# ...                        ...                          ...
# 1095                     False                        False
# 1096                     False                        False
# 1097                     False                        False
# 1098                     False                        False
# 1099                     False                        False
#
#       left canine index casts
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# ...                       ...
# 1095                    False
# 1096                    False
# 1097                    False
# 1098                    False
# 1099                    False
#
# [1100 rows x 14 columns]

# %%
df.notnull()
# Out:
#       Sl No  Sample ID   Age  Gender  inter canine distance intraoral  \
# 0      True      False  True    True                             True
# 1      True      False  True    True                             True
# 2      True      False  True    True                             True
# 3      True      False  True    True                             True
# 4      True      False  True    True                             True
# ...     ...        ...   ...     ...                              ...
# 1095   True      False  True    True                             True
# 1096   True      False  True    True                             True
# 1097   True      False  True    True                             True
# 1098   True      False  True    True                             True
# 1099   True      False  True    True                             True
#
#       intercanine distance casts  right canine width intraoral  \
# 0                           True                          True
# 1                           True                          True
# 2                           True                          True
# 3                           True                          True
# 4                           True                          True
# ...                          ...                           ...
# 1095                        True                          True
# 1096                        True                          True
# 1097                        True                          True
# 1098                        True                          True
# 1099                        True                          True
#
#       right canine width casts  left canine width intraoral  \
# 0                         True                         True
# 1                         True                         True
# 2                         True                         True
# 3                         True                         True
# 4                         True                         True
# ...                        ...                          ...
# 1095                      True                         True
# 1096                      True                         True
# 1097                      True                         True
# 1098                      True                         True
# 1099                      True                         True
#
#       left canine width casts  right canine index intra oral  \
# 0                        True                           True
# 1                        True                           True
# 2                        True                           True
# 3                        True                           True
# 4                        True                           True
# ...                       ...                            ...
# 1095                     True                           True
# 1096                     True                           True
# 1097                     True                           True
# 1098                     True                           True
# 1099                     True                           True
#
#       right canine index casts  left canine index intraoral  \
# 0                         True                         True
# 1                         True                         True
# 2                         True                         True
# 3                         True                         True
# 4                         True                         True
# ...                        ...                          ...
# 1095                      True                         True
# 1096                      True                         True
# 1097                      True                         True
# 1098                      True                         True
# 1099                      True                         True
#
#       left canine index casts
# 0                        True
# 1                        True
# 2                        True
# 3                        True
# 4                        True
# ...                       ...
# 1095                     True
# 1096                     True
# 1097                     True
# 1098                     True
# 1099                     True
#
# [1100 rows x 14 columns]
